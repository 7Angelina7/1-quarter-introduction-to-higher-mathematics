# %%
Задание 1.2

# %%
import math
x = math.sqrt(10**2 + 10**2 + 0**2)
print(x)
# Out:
# 14.142135623730951

# %%
Задание 3.1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
x = []
x2 = []
y = []
y2 = []
for i in range(1500):
    r = 1000
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(r**2 - i**2))
    y2.append(-np.sqrt(r**2 - i**2))
plt.plot(x,y,color='r')
plt.plot(x,y2,color='r')
plt.plot(x2,y2,color='r')
plt.plot(x2,y,color='r')
plt.axis('scaled')
plt.show
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/3846121156.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(r**2 - i**2))
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/3846121156.py:14: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(r**2 - i**2))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Задание 3.2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
x = []
x2 = []
y = []
y2 = []
for i in range(1500):
    r1 = 1000
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(r1**2 - i**2/2))
    y2.append(-np.sqrt(r1**2 - i**2/2))
plt.plot(x,y,color='r')
plt.plot(x,y2,color='r')
plt.plot(x2,y2,color='r')
plt.plot(x2,y,color='r')
plt.axis('scaled')
plt.show
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/2956231732.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(r1**2 - i**2/2))
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/2956231732.py:14: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(r1**2 - i**2/2))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Задание 3.3

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
x = []
x2 = []
y = []
y2 = []
for i in range(1500):
    r1 = 1000
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(r1**2 + i**2/2))
    y2.append(-np.sqrt(r1**2 + i**2/2))
plt.plot(x,y,color='r')
plt.plot(x,y2,color='r')
plt.plot(x2,y2,color='r')
plt.plot(x2,y,color='r')
plt.axis('scaled')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Задание 5.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5,0.5)
X, Y = np.meshgrid(X, Y)
Z = 2*X + 5*Y
Z2 = 4*X + 10*Y
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z2)
ax.scatter(0,0,0,'z',50,'green')
show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/3020845310.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Задание 5.2

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5,0.5)
X, Y = np.meshgrid(X, Y)
Z = X**2 + Y**2
Z2 = X**2/2 + Y**2/2
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z2)
ax.scatter(0,0,0,'z',50,'green')
show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/1216334841.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Задание 33.1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 201)
plt.plot(x, 2*np.cos(x-3) + 4)
plt.plot(x, 5*np.cos(x-6) + 7)
plt.plot(x, 8*np.cos(x-9) + 10)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
Задание 33.3.1

# %%
x = np.linspace(0,5,100)
y = 2*x
plt.plot(x,y)

# %%
x = np.linspace(0,5,100)
y = 2*x
plt.polar(x,y)

# %%
import numpy as np
import math

distance = [10,12,10]
angle= [0,45,90]

coord = []
for i,j in zip(distance,angle):
    coord.append((i*np.cos(math.pi*j/180), i*np.sin(math.pi*j/180)))
print(coord)
# Out:
# [(10.0, 0.0), (8.485281374238571, 8.485281374238571), (6.123233995736766e-16, 10.0)]

# %%
Задание 33.3.2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
p = np.arange(0., 2., 1./180.)*np.pi 
plt.polar(p, [5]*len(p)) 
plt.show()

# %%
Задание 33.3.3

# %%
x = np.linspace(0,5,100)
y = 2/x
plt.polar(x,y)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_18244/1079632230.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   y = 2/x

# %%
Задание 33.4

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.optimize import fsolve
x = np.linspace(-2, 3, 201)
plt.plot(x, (np.exp(x) + x - 1)/x)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1,10)
plt.grid(True)
plt.show
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_13096/3468584687.py:3: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x, (np.exp(x) + x - 1)/x)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.optimize import fsolve

def equations(p):
    x,y = p
    return (y - x**2 + 1, np.exp(x) + x - x*y - 1)
x1, y1 = fsolve(equations, (3, 6))
x2, y2 = fsolve(equations, (-1, 2))

print(x1, y1)
print(x2, y2)
# Out:
# 2.618145573086073 5.8546862418707315
# -1.5818353528924665 1.5022030836705904

# %%
Задание 33.4.1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
x = np.linspace(-3, 3, 201)
#plt.plot(x, (np.exp(x) + x - 1)/x)
plt.plot(x, x**2 - 1)
plt.plot(x, np.exp(x + 2*x - x**3 - 1))
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5,10)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.optimize import fsolve

def equations(p):
    x,y = p
    return (y - x**2 + 1, np.exp(x) + 2*x - x**3 - 1)
x1, y1 = fsolve(equations, (2, 2))    
x2, y2 = fsolve(equations, (-1, 0))
x3, y3 = fsolve(equations, (-2, 3))
print(x1, y1)
print(x2, y2)
print(x3, y3)
# Out:
# 2.6181455730843983 5.854686241864088
# -1.5818353528958682 1.5022030836712312
# -1.5818353528959264 1.5022030836713565
